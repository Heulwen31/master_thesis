# %%
import polars as pl
import matplotlib.pyplot as plt
import seaborn as sns

# %%
df = pl.read_parquet("../data/processed/ieee_cis.parquet")

# %%
df
# Out:
# shape: (590_540, 434)
# ┌─────────┬────────┬───────────────┬───────────────┬───┬───────┬───────┬────────────┬──────────────┐
# │ id      ┆ target ┆ time          ┆ TransactionAm ┆ … ┆ id_37 ┆ id_38 ┆ DeviceType ┆ DeviceInfo   │
# │ ---     ┆ ---    ┆ ---           ┆ t             ┆   ┆ ---   ┆ ---   ┆ ---        ┆ ---          │
# │ i64     ┆ i64    ┆ datetime[ms]  ┆ ---           ┆   ┆ str   ┆ str   ┆ str        ┆ str          │
# │         ┆        ┆               ┆ f64           ┆   ┆       ┆       ┆            ┆              │
# ╞═════════╪════════╪═══════════════╪═══════════════╪═══╪═══════╪═══════╪════════════╪══════════════╡
# │ 2987000 ┆ 0      ┆ 2024-01-02    ┆ 68.5          ┆ … ┆ null  ┆ null  ┆ null       ┆ null         │
# │         ┆        ┆ 00:00:00      ┆               ┆   ┆       ┆       ┆            ┆              │
# │ 2987001 ┆ 0      ┆ 2024-01-02    ┆ 29.0          ┆ … ┆ null  ┆ null  ┆ null       ┆ null         │
# │         ┆        ┆ 00:00:01      ┆               ┆   ┆       ┆       ┆            ┆              │
# │ 2987002 ┆ 0      ┆ 2024-01-02    ┆ 59.0          ┆ … ┆ null  ┆ null  ┆ null       ┆ null         │
# │         ┆        ┆ 00:01:09      ┆               ┆   ┆       ┆       ┆            ┆              │
# │ 2987003 ┆ 0      ┆ 2024-01-02    ┆ 50.0          ┆ … ┆ null  ┆ null  ┆ null       ┆ null         │
# │         ┆        ┆ 00:01:39      ┆               ┆   ┆       ┆       ┆            ┆              │
# │ 2987004 ┆ 0      ┆ 2024-01-02    ┆ 50.0          ┆ … ┆ T     ┆ T     ┆ mobile     ┆ SAMSUNG      │
# │         ┆        ┆ 00:01:46      ┆               ┆   ┆       ┆       ┆            ┆ SM-G892A     │
# │         ┆        ┆               ┆               ┆   ┆       ┆       ┆            ┆ Build/NRD90M │
# │ …       ┆ …      ┆ …             ┆ …             ┆ … ┆ …     ┆ …     ┆ …          ┆ …            │
# │ 3577535 ┆ 0      ┆ 2024-07-01    ┆ 49.0          ┆ … ┆ null  ┆ null  ┆ null       ┆ null         │
# │         ┆        ┆ 23:57:27      ┆               ┆   ┆       ┆       ┆            ┆              │
# │ 3577536 ┆ 0      ┆ 2024-07-01    ┆ 39.5          ┆ … ┆ null  ┆ null  ┆ null       ┆ null         │
# │         ┆        ┆ 23:57:29      ┆               ┆   ┆       ┆       ┆            ┆              │
# │ 3577537 ┆ 0      ┆ 2024-07-01    ┆ 30.95         ┆ … ┆ null  ┆ null  ┆ null       ┆ null         │
# │         ┆        ┆ 23:57:59      ┆               ┆   ┆       ┆       ┆            ┆              │
# │ 3577538 ┆ 0      ┆ 2024-07-01    ┆ 117.0         ┆ … ┆ null  ┆ null  ┆ null       ┆ null         │
# │         ┆        ┆ 23:58:08      ┆               ┆   ┆       ┆       ┆            ┆              │
# │ 3577539 ┆ 0      ┆ 2024-07-01    ┆ 279.95        ┆ … ┆ null  ┆ null  ┆ null       ┆ null         │
# │         ┆        ┆ 23:58:51      ┆               ┆   ┆       ┆       ┆            ┆              │
# └─────────┴────────┴───────────────┴───────────────┴───┴───────┴───────┴────────────┴──────────────┘
