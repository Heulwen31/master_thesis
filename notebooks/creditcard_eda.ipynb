# %%
import polars as pl
import matplotlib.pyplot as plt
import seaborn as sns

# %%
df = pl.read_parquet("../data/processed/ieee_cis.parquet")

# %%
df
# Out:
# shape: (305_601, 373)
# ┌──────────────┬──────────────┬───────┬───────┬───┬─────────────┬───────────┬─────────────┬────────┐
# │ time         ┆ TransactionA ┆ card1 ┆ card2 ┆ … ┆ id_15_Found ┆ id_15_New ┆ id_15_Unkno ┆ target │
# │ ---          ┆ mt           ┆ ---   ┆ ---   ┆   ┆ ---         ┆ ---       ┆ wn          ┆ ---    │
# │ datetime[ns] ┆ ---          ┆ i64   ┆ f64   ┆   ┆ i8          ┆ i8        ┆ ---         ┆ i64    │
# │              ┆ f64          ┆       ┆       ┆   ┆             ┆           ┆ i8          ┆        │
# ╞══════════════╪══════════════╪═══════╪═══════╪═══╪═════════════╪═══════════╪═════════════╪════════╡
# │ 2024-01-02   ┆ 68.5         ┆ 13926 ┆ null  ┆ … ┆ 0           ┆ 0         ┆ 0           ┆ 0      │
# │ 00:00:00     ┆              ┆       ┆       ┆   ┆             ┆           ┆             ┆        │
# │ 2024-01-02   ┆ 59.0         ┆ 4663  ┆ 490.0 ┆ … ┆ 0           ┆ 0         ┆ 0           ┆ 0      │
# ...

# %%
df.shape
# Out:
# (305601, 373)
