# %%
import polars as pl
import matplotlib.pyplot as plt
import seaborn as sns

# %%
df = pl.read_parquet("../data/processed/creditcard_sampled.parquet")

# %%
df
# Out:
# shape: (50_000, 31)
# ┌────────────────┬───────────┬───────────┬───────────┬───┬───────────┬───────────┬────────┬────────┐
# │ time           ┆ V1        ┆ V2        ┆ V3        ┆ … ┆ V27       ┆ V28       ┆ Amount ┆ target │
# │ ---            ┆ ---       ┆ ---       ┆ ---       ┆   ┆ ---       ┆ ---       ┆ ---    ┆ ---    │
# │ datetime[ns]   ┆ f64       ┆ f64       ┆ f64       ┆   ┆ f64       ┆ f64       ┆ f64    ┆ i64    │
# ╞════════════════╪═══════════╪═══════════╪═══════════╪═══╪═══════════╪═══════════╪════════╪════════╡
# │ 2024-01-01     ┆ -1.359807 ┆ -0.072781 ┆ 2.536347  ┆ … ┆ 0.133558  ┆ -0.021053 ┆ 149.62 ┆ 0      │
# │ 00:00:00       ┆           ┆           ┆           ┆   ┆           ┆           ┆        ┆        │
# │ 2024-01-01     ┆ 1.229658  ┆ 0.141004  ┆ 0.045371  ┆ … ┆ 0.034507  ┆ 0.005168  ┆ 4.99   ┆ 0      │
# │ 00:00:04       ┆           ┆           ┆           ┆   ┆           ┆           ┆        ┆        │
# ...

# %%
df.shape
# Out:
# (50000, 31)
